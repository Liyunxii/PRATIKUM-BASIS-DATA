# %% [markdown]
# <a href="https://colab.research.google.com/github/Liyunxii/PRATIKUM-BASIS-DATA/blob/main/Pertemuan3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BAB 3: DATA DEFINITION LANGUANGE (DDL)**
#
# **3.1 IDENTITAS**
# Kompetensi yang ditargetkan pada bab ini adalah:
#
# Memahami SQL dan perintah DDL pada SQL.
#
# Mampu membuat tabel dengan benar beserta relasinya.
#
# Memahami tipe tabel InnoDB.
#
#
# Topik yang dibahas meliputi: SQL, Membuat Tabel, Constraint Relasi, serta Nilai Otomatis dan Nilai Default.
#
# **3.2 TEST AWAL**
# 1. Operasikan perintah SQL untuk :
#
# a. Membuat database
#
# b. Melihat seluruh database pada mysql server
#
# c. Mengakses database/ menggunakan database
#
# d. Menghapus database
#
# 2. Tampilkan hasil screen shoot dan simpan pada folder PrakDB-NIM
#
# a.
#
# ![a. membuat database.png](data:image/png;base64,...)
#
# b.
#
# ![b. melihat seleuruh database.png](data:image/png;base64,...)
#
# c.
#
#  ![c. akses database.png](data:image/png;base64,...)
#
#  d.
#
#  ![d. menghapus database.png](data:image/png;base64,...)
#
#  **3.3 SQL**
#
# Secara umum, perintah-perintah dalam SQL diklasifikasikan menjadi tiga bagian:
#
# 1.   **DDL (Data Definition Language):** Perintah SQL yang berkaitan dengan pendefinisian suatu struktur database (meliputi database dan tabel). Perintahnya: CREATE, ALTER, RENAME, dan DROP.
# 2.   **DML (Data Manipulation Language):** Perintah SQL yang berkaitan dengan manipulasi atau pengolahan data (record) di dalam tabel. Perintahnya: SELECT, INSERT, UPDATE, dan DELETE.
# 3.  **DCL (Data Control Language):** Perintah SQL yang berkaitan dengan manipulasi user dan hak akses (privileges). Perintahnya: GRANT dan REVOKE.
#
# **3.5 CONSTRAINT TABLE**
#
# Constraint adalah aturan atau batasan yang diterapkan pada tabel untuk menjaga integritas dan konsistensi data.
#
# Ada 5 aturan constraint yang umum diterapkan, baik saat membuat tabel (CREATE TABLE) maupun memodifikasi tabel (ALTER TABLE):
#
# 1.   PRIMARY KEY
# 2.   FOREIGN KEY
# 3.   UNIQUE
# 4.   NOT NULL
# 5.   CHECK
#
# Dalam penerapan skema relasi, tabel harus dibuat secara berurutan, dimulai dari tabel kuat (hasil entitas tunggal yang tidak memiliki Foreign Key), baru kemudian dilanjutkan ke tabel hasil relasi.
#
# **3.6 NILAI OTOMATIS DAN NILAI DEFAULT**
#
# *3.6.1 Nilai otomatis / Auto Increment*
#
# Auto Increment adalah mekanisme yang secara otomatis memberikan nilai pada suatu field (biasanya Primary Key), di mana nilai tersebut akan bertambah 1 setiap kali ada penambahan data baru.
#
# *3.6.2 Nilai default*
#
# Nilai default adalah pemberian nilai secara otomatis oleh sistem terhadap field tertentu (umumnya bernilai NULL) jika data tidak diisi. Perintahnya adalah Default Nilai_Default.
#
# **3.7 TYPE : INNODB DAN XTRADB**
#
# **InnoDB:** Merupakan storage engine yang sering digunakan di MySQL, terutama di lingkungan web. Fitur utamanya adalah dukungan transaksi (commit, rollback, dan crash recovery) serta fitur relasi tabel dan integritas melalui Foreign Key. InnoDB menjadi default table engine sejak MySQL versi 5.5.
#
# XtraDB: Merupakan pengganti InnoDB di MariaDB dan dianggap lebih stabil.
#
# Untuk menggunakan tipe mesin tertentu, sintaks Engine = InnoDB; dapat ditambahkan di akhir perintah CREATE TABLE.
